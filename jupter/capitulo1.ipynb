# %% [markdown]
# # Capitulo 1

# %% [markdown]
# Este é o começo do capitulo 1. Para começarmos bem, veja este video:

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('5j3N5WWT3z4', width=800, height=300)

# %% [markdown]
# Agora veja este codigo:

# %%
for i in range(10):
    print(i, end="")
# Out:
# 0123456789

# %% [markdown]
# Agora vejamos este outro video:

# %%
YouTubeVideo('rhE45ihB26E', width=800, height=300)
